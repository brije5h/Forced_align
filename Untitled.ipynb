# %%
# !pip install pynini
# Out:
# ...
#   Using cached pynini-2.1.5.tar.gz (627 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Running setup.py clean for pynini
# Failed to build pynini
# ...
#   Running setup.py install for pynini: started
#   Running setup.py install for pynini: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [48 lines of output]
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-cpython-39
#   creating build\lib.win-amd64-cpython-39\pynini
#   copying pynini\__init__.py -> build\lib.win-amd64-cpython-39\pynini
#   creating build\lib.win-amd64-cpython-39\pywrapfst
#   copying pywrapfst\__init__.py -> build\lib.win-amd64-cpython-39\pywrapfst
#   creating build\lib.win-amd64-cpython-39\pynini\examples
# ...

# %%
from montreal_forced_aligner import align_utils

aligner = align_utils.Aligner(r"C:\Users\brije\Desktop\ForcedAligner\mfa-models-acoustic-english_us_arpa-v2.0.0a", 'dictionary.dict', 'english')
aligner.align('voice.wav', 'Transcript.txt', 'output.TextGrid')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from montreal_forced_aligner import align_utils
#       3 aligner = align_utils.Aligner(r"C:\Users\brije\Desktop\ForcedAligner\mfa-models-acoustic-english_us_arpa-v2.0.0a", 'dictionary.dict', 'english')
#       4 aligner.align('voice.wav', 'Transcript.txt', 'output.TextGrid')
#
# File ~\anaconda3\lib\site-packages\montreal_forced_aligner\__init__.py:4
#       1 """Montreal Forced Aligner is a package for aligning speech corpora through the use of acoustic models and
#       2             dictionaries using Kaldi functionality."""
# ----> 4 import montreal_forced_aligner.acoustic_modeling as acoustic_modeling
#       5 import montreal_forced_aligner.alignment as alignment
#       6 import montreal_forced_aligner.command_line as command_line
#
# ...
