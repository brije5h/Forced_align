# %% [markdown]
# # Forced Alignment with Wav2Vec2
#
# **Author**: [Moto Hira](moto@meta.com)_
#
# This tutorial shows how to align transcript to speech with
# ``torchaudio``, using CTC segmentation algorithm described in
# [CTC-Segmentation of Large Corpora for German End-to-end Speech
# Recognition](https://arxiv.org/abs/2007.09127)_.

# %%
# !python -m pip install --user torchaudio
# Out:
# Requirement already satisfied: torchaudio in c:\users\brije\appdata\roaming\python\python39\site-packages (2.0.2)
# Requirement already satisfied: torch==2.0.1 in c:\users\brije\anaconda3\lib\site-packages (from torchaudio) (2.0.1)
# Requirement already satisfied: jinja2 in c:\users\brije\anaconda3\lib\site-packages (from torch==2.0.1->torchaudio) (2.11.3)
# Requirement already satisfied: filelock in c:\users\brije\anaconda3\lib\site-packages (from torch==2.0.1->torchaudio) (3.6.0)
# Requirement already satisfied: sympy in c:\users\brije\anaconda3\lib\site-packages (from torch==2.0.1->torchaudio) (1.10.1)
# Requirement already satisfied: networkx in c:\users\brije\anaconda3\lib\site-packages (from torch==2.0.1->torchaudio) (2.8.4)
# Requirement already satisfied: typing-extensions in c:\users\brije\anaconda3\lib\site-packages (from torch==2.0.1->torchaudio) (4.3.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\brije\anaconda3\lib\site-packages (from jinja2->torch==2.0.1->torchaudio) (2.0.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\brije\anaconda3\lib\site-packages (from sympy->torch==2.0.1->torchaudio) (1.2.1)

# %%
import torch
import torchaudio

print(torch.__version__)
print(torchaudio.__version__)


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# 2.0.1+cpu
# 2.0.2+cpu
# cpu

# %% [markdown]
# ## Overview
#
# The process of alignment looks like the following.
#
# 1. Estimate the frame-wise label probability from audio waveform
# 2. Generate the trellis matrix which represents the probability of
#    labels aligned at time step.
# 3. Find the most likely path from the trellis matrix.
#
# In this example, we use ``torchaudio``\ ’s ``Wav2Vec2`` model for
# acoustic feature extraction.

# %% [markdown]
# ## Preparation
#
# First we import the necessary packages, and fetch data that we work on.

# %%
# %matplotlib inline

from dataclasses import dataclass

import IPython
import matplotlib
import matplotlib.pyplot as plt

matplotlib.rcParams["figure.figsize"] = [16.0, 4.8]

torch.random.manual_seed(0)

# SPEECH_FILE = torchaudio.utils.download_asset("voice.wav")
SPEECH_FILE = "output.wav"

# Load the WAV file
waveform, sample_rate = torchaudio.load(SPEECH_FILE)

# %% [markdown]
# ## Generate frame-wise label probability
#
# The first step is to generate the label class porbability of each aduio
# frame. We can use a Wav2Vec2 model that is trained for ASR. Here we use
# :py:func:`torchaudio.pipelines.WAV2VEC2_ASR_BASE_960H`.
#
# ``torchaudio`` provides easy access to pretrained models with associated
# labels.
#
# <div class="alert alert-info"><h4>Note</h4><p>In the subsequent sections, we will compute the probability in
#    log-domain to avoid numerical instability. For this purpose, we
#    normalize the ``emission`` with :py:func:`torch.log_softmax`.</p></div>

# %%
bundle = torchaudio.pipelines.WAV2VEC2_ASR_BASE_960H
model = bundle.get_model().to(device)
labels = bundle.get_labels()
with torch.inference_mode():
    waveform, _ = torchaudio.load(SPEECH_FILE)
    emissions, _ = model(waveform.to(device))
    emissions = torch.log_softmax(emissions, dim=-1)

emission = emissions[0].cpu().detach()

# %% [markdown]
# ### Visualization

# %%
print(labels)
plt.imshow(emission.T)
plt.colorbar()
plt.title("Frame-wise class probability")
plt.xlabel("Time")
plt.ylabel("Labels")
plt.show()
# Out:
# ('-', '|', 'E', 'T', 'A', 'O', 'N', 'I', 'H', 'S', 'R', 'D', 'L', 'U', 'M', 'W', 'C', 'F', 'G', 'Y', 'P', 'B', 'V', 'K', "'", 'X', 'J', 'Q', 'Z')

# %% [markdown]
# ## Generate alignment probability (trellis)
#
# From the emission matrix, next we generate the trellis which represents
# the probability of transcript labels occur at each time frame.
#
# Trellis is 2D matrix with time axis and label axis. The label axis
# represents the transcript that we are aligning. In the following, we use
# $t$ to denote the index in time axis and $j$ to denote the
# index in label axis. $c_j$ represents the label at label index
# $j$.
#
# To generate, the probability of time step $t+1$, we look at the
# trellis from time step $t$ and emission at time step $t+1$.
# There are two path to reach to time step $t+1$ with label
# $c_{j+1}$. The first one is the case where the label was
# $c_{j+1}$ at $t$ and there was no label change from
# $t$ to $t+1$. The other case is where the label was
# $c_j$ at $t$ and it transitioned to the next label
# $c_{j+1}$ at $t+1$.
#
# The follwoing diagram illustrates this transition.
#
# <img src="https://download.pytorch.org/torchaudio/tutorial-assets/ctc-forward.png">
#
# Since we are looking for the most likely transitions, we take the more
# likely path for the value of $k_{(t+1, j+1)}$, that is
#
# $k_{(t+1, j+1)} = max( k_{(t, j)} p(t+1, c_{j+1}), k_{(t, j+1)} p(t+1, repeat) )$
#
# where $k$ represents is trellis matrix, and $p(t, c_j)$
# represents the probability of label $c_j$ at time step $t$.
# $repeat$ represents the blank token from CTC formulation. (For the
# detail of CTC algorithm, please refer to the *Sequence Modeling with CTC*
# [[distill.pub](https://distill.pub/2017/ctc/)_])

# %%
import re

# Read text from a TXT file
file_path = 'output.txt'

with open(file_path, 'r', encoding='utf-8') as file:
    text = file.read()

# Remove symbols
text = re.sub(r'\W+', '|', text, flags=re.UNICODE)
text = text.upper()

# Print the modified text
print(text)
# Out:
# OH|UM|WHERE|DID|I|PUT|MY|KEY

# %%
transcript = text
dictionary = {c: i for i, c in enumerate(labels)}

tokens = [dictionary[c] for c in transcript]
print(list(zip(transcript, tokens)))


def get_trellis(emission, tokens, blank_id=0):
    num_frame = emission.size(0)
    num_tokens = len(tokens)

    # Trellis has extra diemsions for both time axis and tokens.
    # The extra dim for tokens represents <SoS> (start-of-sentence)
    # The extra dim for time axis is for simplification of the code.
    trellis = torch.empty((num_frame + 1, num_tokens + 1))
    trellis[0, 0] = 0
    trellis[1:, 0] = torch.cumsum(emission[:, 0], 0)
    trellis[0, -num_tokens:] = -float("inf")
    trellis[-num_tokens:, 0] = float("inf")

    for t in range(num_frame):
        trellis[t + 1, 1:] = torch.maximum(
            # Score for staying at the same token
            trellis[t, 1:] + emission[t, blank_id],
            # Score for changing to the next token
            trellis[t, :-1] + emission[t, tokens],
        )
    return trellis


trellis = get_trellis(emission, tokens)
# Out:
# [('O', 5), ('H', 8), ('|', 1), ('U', 13), ('M', 14), ('|', 1), ('W', 15), ('H', 8), ('E', 2), ('R', 10), ('E', 2), ('|', 1), ('D', 11), ('I', 7), ('D', 11), ('|', 1), ('I', 7), ('|', 1), ('P', 20), ('U', 13), ('T', 3), ('|', 1), ('M', 14), ('Y', 19), ('|', 1), ('K', 23), ('E', 2), ('Y', 19)]

# %%
n = trellis.size()

# %% [markdown]
# ### Visualization

# %%
plt.imshow(trellis[1:, 1:].T, origin="lower")
plt.annotate("- Inf", (trellis.size(1) / 5, trellis.size(1) / 1.5))
plt.colorbar()
plt.show()

# %% [markdown]
# In the above visualization, we can see that there is a trace of high
# probability crossing the matrix diagonally.

# %% [markdown]
# ## Find the most likely path (backtracking)
#
# Once the trellis is generated, we will traverse it following the
# elements with high probability.
#
# We will start from the last label index with the time step of highest
# probability, then, we traverse back in time, picking stay
# ($c_j \rightarrow c_j$) or transition
# ($c_j \rightarrow c_{j+1}$), based on the post-transition
# probability $k_{t, j} p(t+1, c_{j+1})$ or
# $k_{t, j+1} p(t+1, repeat)$.
#
# Transition is done once the label reaches the beginning.
#
# The trellis matrix is used for path-finding, but for the final
# probability of each segment, we take the frame-wise probability from
# emission matrix.

# %%
@dataclass
class Point:
    token_index: int
    time_index: int
    score: float


def backtrack(trellis, emission, tokens, blank_id=0):
    # Note:
    # j and t are indices for trellis, which has extra dimensions
    # for time and tokens at the beginning.
    # When referring to time frame index `T` in trellis,
    # the corresponding index in emission is `T-1`.
    # Similarly, when referring to token index `J` in trellis,
    # the corresponding index in transcript is `J-1`.
    j = trellis.size(1) - 1
    t_start = torch.argmax(trellis[:, j]).item()

    path = []
    for t in range(t_start, 0, -1):
        # 1. Figure out if the current position was stay or change
        # Note (again):
        # `emission[J-1]` is the emission at time frame `J` of trellis dimension.
        # Score for token staying the same from time frame J-1 to T.
        stayed = trellis[t - 1, j] + emission[t - 1, blank_id]
        # Score for token changing from C-1 at T-1 to J at T.
        changed = trellis[t - 1, j - 1] + emission[t - 1, tokens[j - 1]]

        # 2. Store the path with frame-wise probability.
        prob = emission[t - 1, tokens[j - 1] if changed > stayed else 0].exp().item()
        # Return token index and time index in non-trellis coordinate.
        path.append(Point(j - 1, t - 1, prob))

        # 3. Update the token
        if changed > stayed:
            j -= 1
            if j == 0:
                break
    else:
        raise ValueError("Failed to align")
    return path[::-1]


path = backtrack(trellis, emission, tokens)
for p in path:
    print(p)
# Out:
# Point(token_index=0, time_index=39, score=0.11977124214172363)
# Point(token_index=0, time_index=40, score=0.9265798330307007)
# Point(token_index=0, time_index=41, score=0.9148247241973877)
# Point(token_index=0, time_index=42, score=0.9240085482597351)
# Point(token_index=0, time_index=43, score=0.9252396821975708)
# Point(token_index=0, time_index=44, score=0.9379111528396606)
# Point(token_index=0, time_index=45, score=0.6353868842124939)
# Point(token_index=0, time_index=46, score=0.9513844847679138)
# Point(token_index=0, time_index=47, score=0.9427249431610107)
# Point(token_index=0, time_index=48, score=0.9375073909759521)
# Point(token_index=0, time_index=49, score=0.9390591382980347)
# Point(token_index=0, time_index=50, score=0.9436518549919128)
# Point(token_index=0, time_index=51, score=0.9483838677406311)
# Point(token_index=0, time_index=52, score=0.933228611946106)
# Point(token_index=1, time_index=53, score=0.014318273402750492)
# Point(token_index=1, time_index=54, score=0.7604486346244812)
# Point(token_index=1, time_index=55, score=0.5085068941116333)
# Point(token_index=1, time_index=56, score=0.8495504260063171)
# Point(token_index=1, time_index=57, score=0.936974048614502)
# Point(token_index=1, time_index=58, score=0.9252767562866211)
# Point(token_index=1, time_index=59, score=0.926913321018219)
# Point(token_index=1, time_index=60, score=0.9268039464950562)
# Point(token_index=1, time_index=61, score=0.9570788741111755)
# Point(token_index=2, time_index=62, score=0.8757930994033813)
# Point(token_index=2, time_index=63, score=0.9452475905418396)
# Point(token_index=2, time_index=64, score=0.9401770234107971)
# Point(token_index=2, time_index=65, score=0.9377622008323669)
# Point(token_index=2, time_index=66, score=0.3246169090270996)
# Point(token_index=2, time_index=67, score=0.999376118183136)
# Point(token_index=2, time_index=68, score=0.9999560117721558)
# Point(token_index=2, time_index=69, score=0.9999827146530151)
# Point(token_index=2, time_index=70, score=0.9999926090240479)
# Point(token_index=2, time_index=71, score=0.999990701675415)
# Point(token_index=2, time_index=72, score=0.9999949932098389)
# Point(token_index=2, time_index=73, score=0.9999963045120239)
# Point(token_index=2, time_index=74, score=0.9999960660934448)
# Point(token_index=2, time_index=75, score=0.9999966621398926)
# Point(token_index=2, time_index=76, score=0.9999969005584717)
# Point(token_index=2, time_index=77, score=0.9999972581863403)
# Point(token_index=2, time_index=78, score=0.9999973773956299)
# Point(token_index=2, time_index=79, score=0.9999974966049194)
# Point(token_index=2, time_index=80, score=0.9999972581863403)
# Point(token_index=2, time_index=81, score=0.9999973773956299)
# Point(token_index=2, time_index=82, score=0.9999974966049194)
# Point(token_index=2, time_index=83, score=0.9999974966049194)
# Point(token_index=2, time_index=84, score=0.9999977350234985)
# Point(token_index=2, time_index=85, score=0.9999978542327881)
# Point(token_index=2, time_index=86, score=0.9999978542327881)
# Point(token_index=2, time_index=87, score=0.9999980926513672)
# Point(token_index=2, time_index=88, score=0.9999978542327881)
# Point(token_index=2, time_index=89, score=0.9999980926513672)
# Point(token_index=2, time_index=90, score=0.9999982118606567)
# Point(token_index=2, time_index=91, score=0.9999982118606567)
# Point(token_index=2, time_index=92, score=0.9999982118606567)
# Point(token_index=2, time_index=93, score=0.9999983310699463)
# Point(token_index=2, time_index=94, score=0.9999978542327881)
# Point(token_index=2, time_index=95, score=0.9999977350234985)
# Point(token_index=2, time_index=96, score=0.999997615814209)
# Point(token_index=2, time_index=97, score=0.9999979734420776)
# Point(token_index=2, time_index=98, score=0.9999980926513672)
# Point(token_index=2, time_index=99, score=0.9999979734420776)
# Point(token_index=2, time_index=100, score=0.9999979734420776)
# Point(token_index=2, time_index=101, score=0.9999979734420776)
# Point(token_index=2, time_index=102, score=0.9999982118606567)
# Point(token_index=2, time_index=103, score=0.9999984502792358)
# Point(token_index=2, time_index=104, score=0.9999983310699463)
# Point(token_index=2, time_index=105, score=0.9999986886978149)
# Point(token_index=2, time_index=106, score=0.9999984502792358)
# Point(token_index=2, time_index=107, score=0.9999985694885254)
# Point(token_index=2, time_index=108, score=0.9999985694885254)
# Point(token_index=2, time_index=109, score=0.9999986886978149)
# Point(token_index=2, time_index=110, score=0.9999986886978149)
# Point(token_index=2, time_index=111, score=0.9999986886978149)
# Point(token_index=2, time_index=112, score=0.9999985694885254)
# Point(token_index=2, time_index=113, score=0.9999986886978149)
# Point(token_index=2, time_index=114, score=0.999998927116394)
# Point(token_index=2, time_index=115, score=0.9999986886978149)
# Point(token_index=2, time_index=116, score=0.9999988079071045)
# Point(token_index=2, time_index=117, score=0.9999988079071045)
# Point(token_index=2, time_index=118, score=0.9999988079071045)
# Point(token_index=2, time_index=119, score=0.999998927116394)
# Point(token_index=2, time_index=120, score=0.9999988079071045)
# Point(token_index=2, time_index=121, score=0.999998927116394)
# Point(token_index=2, time_index=122, score=0.9999984502792358)
# Point(token_index=2, time_index=123, score=0.9999969005584717)
# Point(token_index=2, time_index=124, score=0.9999983310699463)
# Point(token_index=2, time_index=125, score=0.9999988079071045)
# Point(token_index=2, time_index=126, score=0.99998939037323)
# Point(token_index=2, time_index=127, score=0.9999985694885254)
# Point(token_index=2, time_index=128, score=0.9999986886978149)
# Point(token_index=2, time_index=129, score=0.999998927116394)
# Point(token_index=2, time_index=130, score=0.999998927116394)
# Point(token_index=2, time_index=131, score=0.9999988079071045)
# Point(token_index=2, time_index=132, score=0.9999986886978149)
# Point(token_index=2, time_index=133, score=0.999998927116394)
# Point(token_index=2, time_index=134, score=0.9999984502792358)
# Point(token_index=2, time_index=135, score=0.9999979734420776)
# Point(token_index=2, time_index=136, score=0.9999986886978149)
# Point(token_index=2, time_index=137, score=0.999998927116394)
# Point(token_index=2, time_index=138, score=0.99998939037323)
# Point(token_index=2, time_index=139, score=0.9999986886978149)
# Point(token_index=2, time_index=140, score=0.9999986886978149)
# Point(token_index=2, time_index=141, score=0.9999988079071045)
# Point(token_index=2, time_index=142, score=0.9999988079071045)
# Point(token_index=2, time_index=143, score=0.999998927116394)
# Point(token_index=2, time_index=144, score=0.9999986886978149)
# Point(token_index=2, time_index=145, score=0.9999979734420776)
# Point(token_index=2, time_index=146, score=0.9999980926513672)
# Point(token_index=2, time_index=147, score=0.9999982118606567)
# Point(token_index=2, time_index=148, score=0.9999982118606567)
# Point(token_index=2, time_index=149, score=0.9999980926513672)
# Point(token_index=2, time_index=150, score=0.9999982118606567)
# Point(token_index=2, time_index=151, score=0.9999973773956299)
# Point(token_index=2, time_index=152, score=0.9999982118606567)
# Point(token_index=2, time_index=153, score=0.9999986886978149)
# Point(token_index=2, time_index=154, score=0.9999986886978149)
# Point(token_index=2, time_index=155, score=0.9999977350234985)
# Point(token_index=2, time_index=156, score=0.9999979734420776)
# Point(token_index=2, time_index=157, score=0.9999979734420776)
# Point(token_index=2, time_index=158, score=0.9999979734420776)
# Point(token_index=2, time_index=159, score=0.9999970197677612)
# Point(token_index=2, time_index=160, score=0.9999949932098389)
# Point(token_index=2, time_index=161, score=0.9999942779541016)
# Point(token_index=2, time_index=162, score=0.9999816417694092)
# Point(token_index=2, time_index=163, score=0.999971866607666)
# Point(token_index=2, time_index=164, score=0.9998595714569092)
# Point(token_index=2, time_index=165, score=0.9998897314071655)
# Point(token_index=2, time_index=166, score=0.999702513217926)
# Point(token_index=2, time_index=167, score=0.9989433884620667)
# Point(token_index=2, time_index=168, score=0.9955549836158752)
# Point(token_index=2, time_index=169, score=0.9954524636268616)
# Point(token_index=2, time_index=170, score=0.9716991782188416)
# Point(token_index=2, time_index=171, score=0.9453875422477722)
# Point(token_index=2, time_index=172, score=0.9384442567825317)
# Point(token_index=2, time_index=173, score=0.9624528288841248)
# Point(token_index=2, time_index=174, score=0.970392644405365)
# Point(token_index=2, time_index=175, score=0.9889238476753235)
# Point(token_index=2, time_index=176, score=0.9896538853645325)
# Point(token_index=2, time_index=177, score=0.9927041530609131)
# Point(token_index=2, time_index=178, score=0.9924312829971313)
# Point(token_index=2, time_index=179, score=0.9923702478408813)
# Point(token_index=2, time_index=180, score=0.9922741055488586)
# Point(token_index=2, time_index=181, score=0.9921464323997498)
# Point(token_index=2, time_index=182, score=0.9921191930770874)
# Point(token_index=2, time_index=183, score=0.9882963299751282)
# Point(token_index=2, time_index=184, score=0.984239935874939)
# Point(token_index=2, time_index=185, score=0.9859574437141418)
# Point(token_index=2, time_index=186, score=0.9843789935112)
# Point(token_index=2, time_index=187, score=0.9826161861419678)
# Point(token_index=2, time_index=188, score=0.9868975877761841)
# Point(token_index=2, time_index=189, score=0.9892759323120117)
# Point(token_index=2, time_index=190, score=0.9833868145942688)
# Point(token_index=2, time_index=191, score=0.9831535220146179)
# Point(token_index=2, time_index=192, score=0.9790722727775574)
# Point(token_index=2, time_index=193, score=0.9783198833465576)
# Point(token_index=2, time_index=194, score=0.9804059267044067)
# Point(token_index=2, time_index=195, score=0.9820352792739868)
# Point(token_index=2, time_index=196, score=0.9841761589050293)
# Point(token_index=2, time_index=197, score=0.986868143081665)
# Point(token_index=2, time_index=198, score=0.9858150482177734)
# Point(token_index=2, time_index=199, score=0.9816245436668396)
# Point(token_index=2, time_index=200, score=0.9788587689399719)
# Point(token_index=2, time_index=201, score=0.9850010871887207)
# Point(token_index=2, time_index=202, score=0.9847152233123779)
# Point(token_index=2, time_index=203, score=0.9878559708595276)
# Point(token_index=2, time_index=204, score=0.9877386093139648)
# Point(token_index=2, time_index=205, score=0.9840661883354187)
# Point(token_index=2, time_index=206, score=0.9756473302841187)
# Point(token_index=2, time_index=207, score=0.9698464274406433)
# Point(token_index=2, time_index=208, score=0.9710318446159363)
# Point(token_index=2, time_index=209, score=0.9713265299797058)
# Point(token_index=2, time_index=210, score=0.9629702568054199)
# Point(token_index=2, time_index=211, score=0.984377384185791)
# Point(token_index=2, time_index=212, score=0.9714656472206116)
# Point(token_index=2, time_index=213, score=0.9588531255722046)
# Point(token_index=2, time_index=214, score=0.9620048403739929)
# Point(token_index=2, time_index=215, score=0.9668055176734924)
# Point(token_index=2, time_index=216, score=0.9596756100654602)
# Point(token_index=2, time_index=217, score=0.9701964855194092)
# Point(token_index=2, time_index=218, score=0.9741250872612)
# Point(token_index=2, time_index=219, score=0.9702546000480652)
# Point(token_index=2, time_index=220, score=0.9574006795883179)
# Point(token_index=2, time_index=221, score=0.9472277164459229)
# Point(token_index=2, time_index=222, score=0.9606824517250061)
# Point(token_index=2, time_index=223, score=0.9595033526420593)
# Point(token_index=3, time_index=224, score=0.00586579367518425)
# Point(token_index=4, time_index=225, score=0.010465502738952637)
# Point(token_index=4, time_index=226, score=0.8102519512176514)
# Point(token_index=4, time_index=227, score=0.8458088040351868)
# Point(token_index=4, time_index=228, score=0.7015977501869202)
# Point(token_index=4, time_index=229, score=0.9156033992767334)
# Point(token_index=4, time_index=230, score=0.9623256325721741)
# Point(token_index=4, time_index=231, score=0.8509506583213806)
# Point(token_index=4, time_index=232, score=0.7199822664260864)
# Point(token_index=5, time_index=233, score=0.9259145259857178)
# Point(token_index=5, time_index=234, score=0.999863862991333)
# Point(token_index=5, time_index=235, score=0.9999057054519653)
# Point(token_index=5, time_index=236, score=0.9999394416809082)
# Point(token_index=5, time_index=237, score=0.9999675750732422)
# Point(token_index=5, time_index=238, score=0.9999877214431763)
# Point(token_index=5, time_index=239, score=0.9999886751174927)
# Point(token_index=5, time_index=240, score=0.9999933242797852)
# Point(token_index=5, time_index=241, score=0.9999940395355225)
# Point(token_index=5, time_index=242, score=0.9999943971633911)
# Point(token_index=5, time_index=243, score=0.999996542930603)
# Point(token_index=5, time_index=244, score=0.9999970197677612)
# Point(token_index=5, time_index=245, score=0.9999972581863403)
# Point(token_index=5, time_index=246, score=0.9999972581863403)
# Point(token_index=5, time_index=247, score=0.9999977350234985)
# Point(token_index=5, time_index=248, score=0.999997615814209)
# Point(token_index=5, time_index=249, score=0.9999978542327881)
# Point(token_index=5, time_index=250, score=0.999997615814209)
# Point(token_index=5, time_index=251, score=0.9999979734420776)
# Point(token_index=5, time_index=252, score=0.9999978542327881)
# Point(token_index=5, time_index=253, score=0.9999983310699463)
# Point(token_index=5, time_index=254, score=0.9999979734420776)
# Point(token_index=5, time_index=255, score=0.9999978542327881)
# Point(token_index=5, time_index=256, score=0.9999977350234985)
# Point(token_index=5, time_index=257, score=0.9999974966049194)
# Point(token_index=5, time_index=258, score=0.9999971389770508)
# Point(token_index=5, time_index=259, score=0.9999972581863403)
# Point(token_index=5, time_index=260, score=0.9999980926513672)
# Point(token_index=5, time_index=261, score=0.9999983310699463)
# Point(token_index=5, time_index=262, score=0.9999982118606567)
# Point(token_index=5, time_index=263, score=0.9999982118606567)
# Point(token_index=5, time_index=264, score=0.9999982118606567)
# Point(token_index=5, time_index=265, score=0.9999980926513672)
# Point(token_index=5, time_index=266, score=0.9999982118606567)
# Point(token_index=5, time_index=267, score=0.9999980926513672)
# Point(token_index=5, time_index=268, score=0.9999978542327881)
# Point(token_index=5, time_index=269, score=0.9999982118606567)
# Point(token_index=5, time_index=270, score=0.9999983310699463)
# Point(token_index=5, time_index=271, score=0.9999978542327881)
# Point(token_index=5, time_index=272, score=0.9999982118606567)
# Point(token_index=5, time_index=273, score=0.9999982118606567)
# Point(token_index=5, time_index=274, score=0.9999979734420776)
# Point(token_index=5, time_index=275, score=0.9999979734420776)
# Point(token_index=5, time_index=276, score=0.9999977350234985)
# Point(token_index=5, time_index=277, score=0.99998939037323)
# Point(token_index=5, time_index=278, score=0.9999983310699463)
# Point(token_index=5, time_index=279, score=0.9999984502792358)
# Point(token_index=5, time_index=280, score=0.9999977350234985)
# Point(token_index=5, time_index=281, score=0.9999985694885254)
# Point(token_index=5, time_index=282, score=0.9999984502792358)
# Point(token_index=5, time_index=283, score=0.9999984502792358)
# Point(token_index=5, time_index=284, score=0.9999982118606567)
# Point(token_index=5, time_index=285, score=0.99998939037323)
# Point(token_index=5, time_index=286, score=0.9999985694885254)
# Point(token_index=5, time_index=287, score=0.9999988079071045)
# Point(token_index=5, time_index=288, score=0.9999984502792358)
# Point(token_index=5, time_index=289, score=0.99998939037323)
# Point(token_index=5, time_index=290, score=0.99998939037323)
# Point(token_index=5, time_index=291, score=0.9999983310699463)
# Point(token_index=5, time_index=292, score=0.99998939037323)
# Point(token_index=5, time_index=293, score=0.9999967813491821)
# Point(token_index=5, time_index=294, score=0.99998939037323)
# Point(token_index=5, time_index=295, score=0.9999982118606567)
# Point(token_index=5, time_index=296, score=0.9999984502792358)
# Point(token_index=5, time_index=297, score=0.9999984502792358)
# Point(token_index=5, time_index=298, score=0.9999986886978149)
# Point(token_index=5, time_index=299, score=0.9999980926513672)
# Point(token_index=5, time_index=300, score=0.9999984502792358)
# Point(token_index=5, time_index=301, score=0.99998939037323)
# Point(token_index=5, time_index=302, score=0.9999984502792358)
# Point(token_index=5, time_index=303, score=0.99998939037323)
# Point(token_index=5, time_index=304, score=0.9999960660934448)
# Point(token_index=5, time_index=305, score=0.9999986886978149)
# Point(token_index=5, time_index=306, score=0.9999985694885254)
# Point(token_index=5, time_index=307, score=0.99998939037323)
# Point(token_index=5, time_index=308, score=0.9999979734420776)
# Point(token_index=5, time_index=309, score=0.9999984502792358)
# Point(token_index=5, time_index=310, score=0.9999986886978149)
# Point(token_index=5, time_index=311, score=0.9999984502792358)
# Point(token_index=5, time_index=312, score=0.9999983310699463)
# Point(token_index=5, time_index=313, score=0.9999985694885254)
# Point(token_index=5, time_index=314, score=0.9999986886978149)
# Point(token_index=5, time_index=315, score=0.9999984502792358)
# Point(token_index=5, time_index=316, score=0.9999920129776001)
# Point(token_index=5, time_index=317, score=0.99998939037323)
# Point(token_index=5, time_index=318, score=0.9999986886978149)
# Point(token_index=5, time_index=319, score=0.9999986886978149)
# Point(token_index=5, time_index=320, score=0.9999988079071045)
# Point(token_index=5, time_index=321, score=0.9999986886978149)
# Point(token_index=5, time_index=322, score=0.9999895095825195)
# Point(token_index=5, time_index=323, score=0.9999985694885254)
# Point(token_index=5, time_index=324, score=0.9999984502792358)
# Point(token_index=5, time_index=325, score=0.9999986886978149)
# Point(token_index=5, time_index=326, score=0.9999986886978149)
# Point(token_index=5, time_index=327, score=0.99998939037323)
# Point(token_index=5, time_index=328, score=0.9999983310699463)
# Point(token_index=5, time_index=329, score=0.9999984502792358)
# Point(token_index=5, time_index=330, score=0.9999986886978149)
# Point(token_index=5, time_index=331, score=0.9999986886978149)
# Point(token_index=5, time_index=332, score=0.9999986886978149)
# Point(token_index=5, time_index=333, score=0.9999985694885254)
# Point(token_index=5, time_index=334, score=0.9999970197677612)
# Point(token_index=5, time_index=335, score=0.9999977350234985)
# Point(token_index=5, time_index=336, score=0.9999885559082031)
# Point(token_index=5, time_index=337, score=0.99998939037323)
# Point(token_index=5, time_index=338, score=0.9999936819076538)
# Point(token_index=5, time_index=339, score=0.99998939037323)
# Point(token_index=5, time_index=340, score=0.99998939037323)
# Point(token_index=5, time_index=341, score=0.9999918937683105)
# Point(token_index=5, time_index=342, score=0.9999709129333496)
# Point(token_index=5, time_index=343, score=0.9999699592590332)
# Point(token_index=5, time_index=344, score=0.9999607801437378)
# Point(token_index=5, time_index=345, score=0.9999390840530396)
# Point(token_index=5, time_index=346, score=0.9998962879180908)
# Point(token_index=5, time_index=347, score=0.99998939037323)
# Point(token_index=5, time_index=348, score=0.9997261166572571)
# Point(token_index=5, time_index=349, score=0.9994500279426575)
# Point(token_index=5, time_index=350, score=0.9990222454071045)
# Point(token_index=5, time_index=351, score=0.99998939037323)
# Point(token_index=5, time_index=352, score=0.9984000325202942)
# Point(token_index=5, time_index=353, score=0.9988251328468323)
# Point(token_index=5, time_index=354, score=0.998701810836792)
# Point(token_index=5, time_index=355, score=0.9977776408195496)
# Point(token_index=5, time_index=356, score=0.9984706044197083)
# Point(token_index=5, time_index=357, score=0.9964242577552795)
# Point(token_index=5, time_index=358, score=0.9950856566429138)
# Point(token_index=5, time_index=359, score=0.9942626357078552)
# Point(token_index=6, time_index=360, score=0.8511747121810913)
# Point(token_index=7, time_index=361, score=0.026185067370533943)
# Point(token_index=7, time_index=362, score=0.9834190607070923)
# Point(token_index=7, time_index=363, score=0.9847709536552429)
# Point(token_index=7, time_index=364, score=0.9832512736320496)
# Point(token_index=7, time_index=365, score=0.986009955406189)
# Point(token_index=7, time_index=366, score=0.9862688183784485)
# Point(token_index=7, time_index=367, score=0.9865673780441284)
# Point(token_index=7, time_index=368, score=0.9864734411239624)
# Point(token_index=7, time_index=369, score=0.986829936504364)
# Point(token_index=7, time_index=370, score=0.9877568483352661)
# Point(token_index=7, time_index=371, score=0.9884650707244873)
# Point(token_index=7, time_index=372, score=0.9887040257453918)
# Point(token_index=8, time_index=373, score=0.7757068872451782)
# Point(token_index=8, time_index=374, score=0.9378983378410339)
# Point(token_index=9, time_index=375, score=0.04135269671678543)
# Point(token_index=9, time_index=376, score=0.9923426508903503)
# Point(token_index=9, time_index=377, score=0.9952943921089172)
# Point(token_index=10, time_index=378, score=0.02521752007305622)
# Point(token_index=10, time_index=379, score=0.6023131012916565)
# Point(token_index=11, time_index=380, score=0.9163280725479126)
# Point(token_index=11, time_index=381, score=0.9830672144889832)
# Point(token_index=11, time_index=382, score=0.9843815565109253)
# Point(token_index=12, time_index=383, score=3.566835403034929e-06)
# Point(token_index=12, time_index=384, score=0.9033180475234985)
# Point(token_index=12, time_index=385, score=0.9180408120155334)
# Point(token_index=12, time_index=386, score=0.9832111597061157)
# Point(token_index=13, time_index=387, score=0.6059649586677551)
# Point(token_index=13, time_index=388, score=0.6265962719917297)
# Point(token_index=13, time_index=389, score=0.6258953809738159)
# Point(token_index=13, time_index=390, score=0.22303731739521027)
# Point(token_index=13, time_index=391, score=0.8554007411003113)
# Point(token_index=13, time_index=392, score=0.9907646179199219)
# Point(token_index=14, time_index=393, score=0.0020155697129666805)
# Point(token_index=14, time_index=394, score=0.9706299304962158)
# Point(token_index=15, time_index=395, score=0.8370715379714966)
# Point(token_index=15, time_index=396, score=0.20706383883953094)
# Point(token_index=15, time_index=397, score=0.9952661991119385)
# Point(token_index=15, time_index=398, score=0.9983503818511963)
# Point(token_index=15, time_index=399, score=0.9984732270240784)
# Point(token_index=15, time_index=400, score=0.5053467750549316)
# Point(token_index=15, time_index=401, score=0.9368122816085815)
# Point(token_index=15, time_index=402, score=0.9181849956512451)
# Point(token_index=15, time_index=403, score=0.9516354203224182)
# Point(token_index=15, time_index=404, score=0.9585370421409607)
# Point(token_index=15, time_index=405, score=0.9590727090835571)
# Point(token_index=15, time_index=406, score=0.9296808838844299)
# Point(token_index=16, time_index=407, score=0.41957658529281616)
# Point(token_index=16, time_index=408, score=0.8283011317253113)
# Point(token_index=16, time_index=409, score=0.8514647483825684)
# Point(token_index=16, time_index=410, score=0.885653018951416)
# Point(token_index=16, time_index=411, score=0.8931527733802795)
# Point(token_index=16, time_index=412, score=0.8837974667549133)
# Point(token_index=16, time_index=413, score=0.8856159448623657)
# Point(token_index=16, time_index=414, score=0.9133932590484619)
# Point(token_index=16, time_index=415, score=0.908474862575531)
# Point(token_index=16, time_index=416, score=0.05459939315915108)
# Point(token_index=17, time_index=417, score=0.9450260996818542)
# Point(token_index=17, time_index=418, score=0.9991139769554138)
# Point(token_index=17, time_index=419, score=0.9994227886199951)
# Point(token_index=17, time_index=420, score=0.9995331764221191)
# Point(token_index=17, time_index=421, score=0.9994913339614868)
# Point(token_index=17, time_index=422, score=0.9995388984680176)
# Point(token_index=17, time_index=423, score=0.9994435906410217)
# Point(token_index=17, time_index=424, score=0.9994533658027649)
# Point(token_index=17, time_index=425, score=0.9994944334030151)
# Point(token_index=17, time_index=426, score=0.9993472695350647)
# Point(token_index=17, time_index=427, score=0.9989830851554871)
# Point(token_index=17, time_index=428, score=0.999090313911438)
# Point(token_index=17, time_index=429, score=0.9992903470993042)
# Point(token_index=18, time_index=430, score=0.1264292597770691)
# Point(token_index=18, time_index=431, score=0.753167450428009)
# Point(token_index=18, time_index=432, score=0.6332510113716125)
# Point(token_index=18, time_index=433, score=0.9924463629722595)
# Point(token_index=18, time_index=434, score=0.9957162737846375)
# Point(token_index=18, time_index=435, score=0.994606077671051)
# Point(token_index=18, time_index=436, score=0.9942904710769653)
# Point(token_index=18, time_index=437, score=0.9910755157470703)
# Point(token_index=19, time_index=438, score=0.17647957801818848)
# Point(token_index=19, time_index=439, score=0.6667603254318237)
# Point(token_index=19, time_index=440, score=0.9489994049072266)
# Point(token_index=19, time_index=441, score=0.9738513827323914)
# Point(token_index=20, time_index=442, score=0.14687100052833557)
# Point(token_index=20, time_index=443, score=0.9128820300102234)
# Point(token_index=20, time_index=444, score=0.9323310852050781)
# Point(token_index=20, time_index=445, score=0.26654237508773804)
# Point(token_index=21, time_index=446, score=0.8430927991867065)
# Point(token_index=21, time_index=447, score=0.9992783665657043)
# Point(token_index=21, time_index=448, score=0.999467670917511)
# Point(token_index=21, time_index=449, score=0.999549925327301)
# Point(token_index=21, time_index=450, score=0.9995317459106445)
# Point(token_index=21, time_index=451, score=0.9995993971824646)
# Point(token_index=21, time_index=452, score=0.9996620416641235)
# Point(token_index=21, time_index=453, score=0.9995924830436707)
# Point(token_index=21, time_index=454, score=0.9996156692504883)
# Point(token_index=21, time_index=455, score=0.999775230884552)
# Point(token_index=21, time_index=456, score=0.9997765421867371)
# Point(token_index=21, time_index=457, score=0.9995303153991699)
# Point(token_index=21, time_index=458, score=0.9995229244232178)
# Point(token_index=22, time_index=459, score=0.0005657008732669055)
# Point(token_index=22, time_index=460, score=0.8956789374351501)
# Point(token_index=22, time_index=461, score=0.8762686848640442)
# Point(token_index=22, time_index=462, score=0.9000521302223206)
# Point(token_index=22, time_index=463, score=0.83472740650177)
# Point(token_index=22, time_index=464, score=0.7245597243309021)
# Point(token_index=22, time_index=465, score=0.7582876682281494)
# Point(token_index=22, time_index=466, score=0.6854211091995239)
# Point(token_index=23, time_index=467, score=0.0019476815359666944)
# Point(token_index=23, time_index=468, score=0.7957108020782471)
# Point(token_index=23, time_index=469, score=0.9536764025688171)
# Point(token_index=23, time_index=470, score=0.9199650287628174)
# Point(token_index=23, time_index=471, score=0.9036858081817627)
# Point(token_index=23, time_index=472, score=0.9077224135398865)
# Point(token_index=23, time_index=473, score=0.8744215965270996)
# Point(token_index=24, time_index=474, score=0.14012372493743896)
# Point(token_index=25, time_index=475, score=9.312227484770119e-05)
# Point(token_index=25, time_index=476, score=0.9647621512413025)
# Point(token_index=25, time_index=477, score=0.9882722496986389)
# Point(token_index=26, time_index=478, score=0.1637166291475296)
# Point(token_index=26, time_index=479, score=0.20162448287010193)
# Point(token_index=26, time_index=480, score=0.9772841930389404)
# Point(token_index=26, time_index=481, score=0.9822737574577332)
# Point(token_index=26, time_index=482, score=0.9859248995780945)
# Point(token_index=27, time_index=483, score=0.0017659415025264025)

# %% [markdown]
# ### Visualization

# %%
def plot_trellis_with_path(trellis, path):
    # To plot trellis with path, we take advantage of 'nan' value
    trellis_with_path = trellis.clone()
    for _, p in enumerate(path):
        trellis_with_path[p.time_index, p.token_index] = float("nan")
    plt.imshow(trellis_with_path[1:, 1:].T, origin="lower")


plot_trellis_with_path(trellis, path)
plt.title("The path found by backtracking")
plt.show()

# %% [markdown]
# Looking good. Now this path contains repetations for the same labels, so
# let’s merge them to make it close to the original transcript.
#
# When merging the multiple path points, we simply take the average
# probability for the merged segments.

# %%
# Merge the labels
@dataclass
class Segment:
    label: str
    start: int
    end: int
    score: float

    def __repr__(self):
        return f"{self.label}\t({self.score:4.2f}): [{self.start:5d}, {self.end:5d})"

    @property
    def length(self):
        return self.end - self.start


def merge_repeats(path):
    i1, i2 = 0, 0
    segments = []
    while i1 < len(path):
        while i2 < len(path) and path[i1].token_index == path[i2].token_index:
            i2 += 1
        score = sum(path[k].score for k in range(i1, i2)) / (i2 - i1)
        segments.append(
            Segment(
                transcript[path[i1].token_index],
                path[i1].time_index,
                path[i2 - 1].time_index + 1,
                score,
            )
        )
        i1 = i2
    return segments


segments = merge_repeats(path)
for seg in segments:
    print(seg)
# Out:
# O	(0.86): [   39,    53)
# H	(0.76): [   53,    62)
# |	(0.99): [   62,   224)
# U	(0.01): [  224,   225)
# M	(0.73): [  225,   233)
# |	(1.00): [  233,   360)
# W	(0.85): [  360,   361)
# H	(0.91): [  361,   373)
# E	(0.86): [  373,   375)
# R	(0.68): [  375,   378)
# E	(0.31): [  378,   380)
# |	(0.96): [  380,   383)
# D	(0.70): [  383,   387)
# I	(0.65): [  387,   393)
# D	(0.49): [  393,   395)
# |	(0.85): [  395,   407)
# I	(0.75): [  407,   417)
# |	(1.00): [  417,   430)
# P	(0.81): [  430,   438)
# U	(0.69): [  438,   442)
# T	(0.56): [  442,   446)
# |	(0.99): [  446,   459)
# M	(0.71): [  459,   467)
# Y	(0.77): [  467,   474)
# |	(0.14): [  474,   475)
# K	(0.65): [  475,   478)
# E	(0.66): [  478,   483)
# Y	(0.00): [  483,   484)

# %% [markdown]
# ### Visualization

# %%
def plot_trellis_with_segments(trellis, segments, transcript):
    # To plot trellis with path, we take advantage of 'nan' value
    trellis_with_path = trellis.clone()
    for i, seg in enumerate(segments):
        if seg.label != "|":
            trellis_with_path[seg.start + 1 : seg.end + 1, i + 1] = float("nan")

    fig, [ax1, ax2] = plt.subplots(2, 1, figsize=(16, 9.5))
    ax1.set_title("Path, label and probability for each label")
    ax1.imshow(trellis_with_path.T, origin="lower")
    ax1.set_xticks([])

    for i, seg in enumerate(segments):
        if seg.label != "|":
            ax1.annotate(seg.label, (seg.start + 0.7, i + 0.3), weight="bold")
            ax1.annotate(f"{seg.score:.2f}", (seg.start - 0.3, i + 4.3))

    ax2.set_title("Label probability with and without repetation")
    xs, hs, ws = [], [], []
    for seg in segments:
        if seg.label != "|":
            xs.append((seg.end + seg.start) / 2 + 0.4)
            hs.append(seg.score)
            ws.append(seg.end - seg.start)
            ax2.annotate(seg.label, (seg.start + 0.8, -0.07), weight="bold")
    ax2.bar(xs, hs, width=ws, color="gray", alpha=0.5, edgecolor="black")

    xs, hs = [], []
    for p in path:
        label = transcript[p.token_index]
        if label != "|":
            xs.append(p.time_index + 1)
            hs.append(p.score)

    ax2.bar(xs, hs, width=0.5, alpha=0.5)
    ax2.axhline(0, color="black")
    ax2.set_xlim(ax1.get_xlim())
    ax2.set_ylim(-0.1, 1.1)


plot_trellis_with_segments(trellis, segments, transcript)
plt.tight_layout()
plt.show()

# %% [markdown]
# Looks good. Now let’s merge the words. The Wav2Vec2 model uses ``'|'``
# as the word boundary, so we merge the segments before each occurance of
# ``'|'``.
#
# Then, finally, we segment the original audio into segmented audio and
# listen to them to see if the segmentation is correct.

# %%
# Merge words
def merge_words(segments, separator="|"):
    words = []
    i1, i2 = 0, 0
    while i1 < len(segments):
        if i2 >= len(segments) or segments[i2].label == separator:
            if i1 != i2:
                segs = segments[i1:i2]
                word = "".join([seg.label for seg in segs])
                score = sum(seg.score * seg.length for seg in segs) / sum(seg.length for seg in segs)
                words.append(Segment(word, segments[i1].start, segments[i2 - 1].end, score))
            i1 = i2 + 1
            i2 = i1
        else:
            i2 += 1
    return words


word_segments = merge_words(segments)
for word in word_segments:
    print(word)
# Out:
# OH	(0.82): [   39,    62)
# UM	(0.65): [  224,   233)
# WHERE	(0.80): [  360,   380)
# DID	(0.64): [  383,   395)
# I	(0.75): [  407,   417)
# PUT	(0.72): [  430,   446)
# MY	(0.74): [  459,   474)
# KEY	(0.59): [  475,   484)

# %% [markdown]
# ### Visualization

# %%
def plot_alignments(trellis, segments, word_segments, waveform):
    trellis_with_path = trellis.clone()
    for i, seg in enumerate(segments):
        if seg.label != "|":
            trellis_with_path[seg.start + 1 : seg.end + 1, i + 1] = float("nan")

    fig, [ax1, ax2] = plt.subplots(2, 1, figsize=(16, 9.5))

    ax1.imshow(trellis_with_path[1:, 1:].T, origin="lower")
    ax1.set_xticks([])
    ax1.set_yticks([])

    for word in word_segments:
        ax1.axvline(word.start - 0.5)
        ax1.axvline(word.end - 0.5)

    for i, seg in enumerate(segments):
        if seg.label != "|":
            ax1.annotate(seg.label, (seg.start, i + 0.3))
            ax1.annotate(f"{seg.score:.2f}", (seg.start, i + 4), fontsize=8)

    # The original waveform
    ratio = waveform.size(0) / (trellis.size(0) - 1)
    ax2.plot(waveform)
    for word in word_segments:
        x0 = ratio * word.start
        x1 = ratio * word.end
        ax2.axvspan(x0, x1, alpha=0.1, color="red")
        ax2.annotate(f"{word.score:.2f}", (x0, 0.8))

    for seg in segments:
        if seg.label != "|":
            ax2.annotate(seg.label, (seg.start * ratio, 0.9))
    xticks = ax2.get_xticks()
    plt.xticks(xticks, xticks / bundle.sample_rate)
    ax2.set_xlabel("time [second]")
    ax2.set_yticks([])
    ax2.set_ylim(-1.0, 1.0)
    ax2.set_xlim(0, waveform.size(-1))


plot_alignments(
    trellis,
    segments,
    word_segments,
    waveform[0],
)
plt.show()

# %%
# A trick to embed the resulting audio to the generated file.
# `IPython.display.Audio` has to be the last call in a cell,
# and there should be only one call par cell.
def display_segment(i):
    ratio = waveform.size(1) / (trellis.size(0) - 1)
    word = word_segments[i]
    x0 = int(ratio * word.start)
    x1 = int(ratio * word.end)
    print(f"{word.label} ({word.score:.2f}): {x0 / bundle.sample_rate:.3f} - {x1 / bundle.sample_rate:.3f} sec")
    segment = waveform[:, x0:x1]
    return IPython.display.Audio(segment.numpy(), rate=bundle.sample_rate)

# %%
# Generate the audio for each segment
print(transcript)
IPython.display.Audio(SPEECH_FILE)
# Out:
# OH|UM|WHERE|DID|I|PUT|MY|KEY
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
display_segment(0)
# Out:
# OH (0.82): 0.781 - 1.242 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
display_segment(1)
# Out:
# UM (0.65): 4.487 - 4.668 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
display_segment(2)
# Out:
# WHERE (0.80): 7.212 - 7.613 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
display_segment(3)
# Out:
# DID (0.64): 7.673 - 7.913 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
display_segment(4)
# Out:
# I (0.75): 8.154 - 8.354 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
display_segment(5)
# Out:
# PUT (0.72): 8.614 - 8.935 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
display_segment(6)
# Out:
# MY (0.74): 9.195 - 9.496 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
display_segment(7)
# Out:
# KEY (0.59): 9.516 - 9.696 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
display_segment(8)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 display_segment(8)
#
# Cell In[40], line 6, in display_segment(i)
#       4 def display_segment(i):
#       5     ratio = waveform.size(1) / (trellis.size(0) - 1)
# ----> 6     word = word_segments[i]
#       7     x0 = int(ratio * word.start)
#       8     x1 = int(ratio * word.end)
#
# IndexError: list index out of range

# %% [markdown]
# ## Conclusion
#
# In this tutorial, we looked how to use torchaudio’s Wav2Vec2 model to
# perform CTC segmentation for forced alignment.
